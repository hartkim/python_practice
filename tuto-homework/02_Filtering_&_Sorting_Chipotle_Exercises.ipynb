# %% [markdown]
# # Ex1 - Filtering and Sorting Data
#
# Check out [Chipotle Exercises Video Tutorial](https://youtu.be/ZZPiWZpdekA) to watch a data scientist go through the exercises

# %% [markdown]
# ### Step 1. 필요한 라이브러리를 import 하세요

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. 다음 경로의 dataset을 import 하세요 [address](https://raw.githubusercontent.com/myoh0623/dataset/main/chipotle.tsv).

# %%
url ='https://raw.githubusercontent.com/myoh0623/dataset/main/chipotle.tsv'

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv(url, sep='\t')
# 참고 확장자가 csv가 아니라 tsv파일
# tsv 부르는 법

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo.shape
# Out:
# (4622, 5)

# %% [markdown]
# ### Step 4. $10.00 이상인 제품이 몇 개 있습니까?
# #### 같은 항목이면 비싼 물품 기준

# %%
# item_price의 값들을 float으로 변경해 보세요

# 나의 코드 근데 아까는 item_price가 한번 더 들어갔는데 왜 이제는 괜찮지?
chipo["item_price"]=chipo["item_price"].str.replace(pat=r'$', repl=r'', regex=True)

# %%
chipo.item_price[0] # '$2.39 ' 라서 $를 없애줘야한다.
# Out:
# '$2.39 '

# %%
# 강사님 코드
# float으로 바꾸기
# float(chipo.item_price[0][1:])
chipo.item_price = pd.Series(map(lambda x : float(x[1:]), chipo.item_price))
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
# 강사님 코드
# 주문횟수 1 그리고 10달러 이상인 것들 뽑기
one_list = (chipo.quantity ==1) & (chipo.item_price >= 10)
chipo[one_list].item_name.nunique() #nunique는 item_name이 겹치지 않는 애들을 가져온다
# Out:
# 25

# %%
# 강사님코드
# 품목별로 묶고 max값 df 저장
# 저장한 값에서 10달러 이상인 것 값 세기
df = chipo.groupby("item_name").max() 
len(df[df.item_price >=10])
# Out:
# 31

# %%
df
# Out:
#                                        order_id  quantity  \
# item_name
# 6 Pack Soft Drink                           129         1
# Barbacoa Bowl                                19         1
# Barbacoa Burrito                             11         1
# Barbacoa Crispy Tacos                        75         1
# Barbacoa Salad Bowl                         501         1
# Barbacoa Soft Tacos                          26         1
# Bottled Water                                17         1
# Bowl                                        193         1
# Burrito                                     214         1
# Canned Soda                                   9         1
# Canned Soft Drink                           114         1
# Carnitas Bowl                                17         1
# Carnitas Burrito                             14         1
# Carnitas Crispy Tacos                       230         1
# Carnitas Salad                             1500         1
# ...

# %%
chipo[chipo.item_price >= 10].count()
# 1130개
# Out:
# order_id              1130
# quantity              1130
# item_name             1130
# choice_description    1123
# item_price            1130
# dtype: int64

# %% [markdown]
# ### Step 5. 각 품목의 가격은 얼마입니까?
# ###### item_name 과 item_price 만 출력하시오

# %%
one_qu=chipo[chipo.quantity ==1]

# %%
# 어쩔때 min,max를 쓰는거지?
one_qu.groupby("item_name").min().sort_values(by="item_price",ascending=False)
# Out:
#                                        order_id  quantity  \
# item_name
# Steak Salad Bowl                            250         1
# Barbacoa Salad Bowl                         501         1
# Carnitas Salad Bowl                         468         1
# Carnitas Soft Tacos                         103         1
# Carnitas Crispy Tacos                       230         1
# Steak Soft Tacos                              4         1
# Carnitas Salad                             1500         1
# Carnitas Bowl                                17         1
# Barbacoa Soft Tacos                          26         1
# Barbacoa Crispy Tacos                        75         1
# Veggie Salad Bowl                            83         1
# Chicken Salad Bowl                           20         1
# Steak Burrito                                 4         1
# Steak Crispy Tacos                           40         1
# Steak Salad                                 276         1
# ...

# %%
# 각 품목의 가격.. 품목별 가격 이니까 group by?
a =chipo.groupby("item_name")[['item_price']].mean()

# %%
a.sort_values(by="item_price",ascending=False)
# Out:
#                                        item_price
# item_name
# Bowl                                    14.800000
# Steak Salad Bowl                        11.847931
# Chicken Salad Bowl                      11.170455
# Carnitas Crispy Tacos                   11.137143
# Carnitas Salad Bowl                     11.056667
# Barbacoa Crispy Tacos                   10.928182
# Carnitas Bowl                           10.833971
# Steak Bowl                              10.711801
# Barbacoa Salad Bowl                     10.640000
# Veggie Soft Tacos                       10.565714
# Steak Burrito                           10.465842
# Veggie Bowl                             10.211647
# Steak Crispy Tacos                      10.209714
# Barbacoa Bowl                           10.187273
# Veggie Salad Bowl                       10.138889
# Carnitas Burrito                        10.132712
# Chicken Bowl                            10.113953
# Chicken Burrito                         10.082857
# ...

# %%
# 강사님 코드
chipo[["item_name","item_price"]].groupby("item_name").min()
# Out:
#                                        item_price
# item_name
# 6 Pack Soft Drink                            6.49
# Barbacoa Bowl                                8.69
# Barbacoa Burrito                             8.69
# Barbacoa Crispy Tacos                        8.99
# Barbacoa Salad Bowl                          9.39
# Barbacoa Soft Tacos                          8.99
# Bottled Water                                1.09
# Bowl                                         7.40
# Burrito                                      7.40
# Canned Soda                                  1.09
# Canned Soft Drink                            1.25
# Carnitas Bowl                                8.99
# Carnitas Burrito                             8.69
# Carnitas Crispy Tacos                        8.99
# Carnitas Salad                               8.99
# Carnitas Salad Bowl                          9.39
# Carnitas Soft Tacos                          8.99
# Chicken Bowl                                 8.19
# ...

# %% [markdown]
# ### Step 6. item_name으로 정렬하세요

# %%
chipo.sort_values(by="item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %%
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description item_price
# 3389                                        [Diet Coke]    $12.98
# 341                                         [Diet Coke]     $6.49
# 1849                                             [Coke]     $6.49
# 1860                                        [Diet Coke]     $6.49
# 2713                                             [Coke]     $6.49
# ...

# %% [markdown]
# ### Step 7. 가장 비싼 품목의 주문 수량은 몇개입니까?

# %%
very=chipo.sort_values(by="item_price",ascending=False)

# %%
very
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 3936      1578         1                   Canned Soda
# 2922      1162         1                 Bottled Water
# 1396       567         1                   Canned Soda
# 2562      1014         1                   Canned Soda
# 1457       591         1                   Canned Soda
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00
# ...

# %%
very.iloc[[0]]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
# 강사님 코드
chipo.sort_values(by ="item_price",ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
# 단품이 비싼걸 찾아내려면
chipo["single_price"] = chipo["item_price"]/chipo["quantity"]

# %%
chipo.sort_values(by ="single_price",ascending=False).head(1)
# Out:
#       order_id  quantity            item_name  \
# 2442       970         1  Barbacoa Salad Bowl
#
#                                      choice_description  item_price  \
# 2442  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...       11.89
#
#       single_price
# 2442         11.89

# %% [markdown]
# ### Step 8. Veggie Salad Bowl은 몇번 주문 되었습니까?

# %%
chipo[chipo["item_name"] == "Veggie Salad Bowl"].count()
# Out:
# order_id              18
# quantity              18
# item_name             18
# choice_description    18
# item_price            18
# dtype: int64

# %%
# 강사님 코드
chipo_salad = chipo[chipo.item_name == "Veggie Salad Bowl"]
len(chipo_salad)
# Out:
# 18

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 9. Canned Soda를 두 개 이상 주문한 횟수는 몇번입니까?

# %%
chipo[chipo["item_name"] == "Canned Soda"]
# Out:
#       order_id  quantity    item_name choice_description item_price
# 18           9         2  Canned Soda           [Sprite]     $2.18
# 28          14         1  Canned Soda       [Dr. Pepper]     $1.09
# 51          23         2  Canned Soda     [Mountain Dew]     $2.18
# 53          24         1  Canned Soda           [Sprite]     $1.09
# 107         47         1  Canned Soda       [Dr. Pepper]     $1.09
# ...        ...       ...          ...                ...        ...
# 3897      1562         1  Canned Soda     [Mountain Dew]     $1.09
# 3926      1575         1  Canned Soda       [Dr. Pepper]     $1.09
# 3936      1578         1  Canned Soda  [Diet Dr. Pepper]     $1.09
# 4008      1604         1  Canned Soda        [Diet Coke]     $1.09
# 4051      1621         1  Canned Soda           [Sprite]     $1.09
#
# [104 rows x 5 columns]

# %%
# 방법 1 : 길어서 한개 변수에 할당하고 끊어서 적용하기
soda = chipo[chipo.item_name == "Canned Soda"]

# %%
soda[soda["quantity"] >=2].count()
# Out:
# order_id              20
# quantity              20
# item_name             20
# choice_description    20
# item_price            20
# dtype: int64

# %%
# 방법 2 : 그냥 줄줄 이어쓰기
chipo[chipo.item_name == "Canned Soda"][chipo[chipo.item_name == "Canned Soda"]["quantity"] >=2].count()
# Out:
# order_id              20
# quantity              20
# item_name             20
# choice_description    20
# item_price            20
# dtype: int64

# %%
# 강사님 코드
chipo_drink = chipo[(chipo.item_name =="Canned Soda") & (chipo.quantity >=2)]
print(chipo_drink.shape) # 20번 주문
# Out:
# (20, 6)
