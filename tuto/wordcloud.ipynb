# %%
# !conda install -y WordCloud
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /home/user/anaconda3/envs/pandas
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     wordcloud-1.9.2            |   py39h5eee18b_0         184 KB
#     ------------------------------------------------------------
#                                            Total:         184 KB
#
# The following NEW packages will be INSTALLED:
#
#   wordcloud          pkgs/main/linux-64::wordcloud-1.9.2-py39h5eee18b_0
#
#
#
# ...
#
# Preparing transaction: done
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
# import wordcloud

# %%
saramin = pd.read_csv('./saramin.csv')

# %%
saramin= saramin['기업명']

# %%
saramin
# Out:
# 0         [쿠팡로지스틱스서비스] HR Recruiting 데이터 분석 지원
# 1                          데이터관리부(자료팀) 신입사원 모집
# 2                     Chat GPT 활용 데이터 생성 아르바이트
# 3                  데이터 애널리스트 인턴 (Data Analyst)
# 4                통계 분석 및 GIS 분석의 데이터 분석가 모십니다.
#                         ...
# 195                            웹사이트 운영관리 신입 채용
# 196    [NIT Service] NAVER, LINE 서비스 공통 플랫폼 운영
# 197            [NIT Service] NAVER/LINE 서비스 관제
# 198                 포인드(주) 인공지능·딥러닝 개발자(신입) 채용
# 199                 넥스블루 DataBase 엔지니어 신입 공채모집
# Name: 기업명, Length: 200, dtype: object

# %%
text='''
쿠팡로지스틱스서비스(유)
(주)옥션원
(주)이노버즈
(주)프라이데이즈랩
(주)더원테크
한국딥러닝(주)
알테어엔지니어링(주)
(주)삼원유토피아시스템
이크론소프트
(주)에프앤가이드
(주)올림데이터랩
(주)더원테크
(주)더원테크
(주)앤커웨이브
(주)광개토연구소
주식회사 루트시스템즈
㈜아이커머
(주)스포티스틱스
(주)광개토연구소
(주)제이앤피메디
(주)나루데이타
(주)디투에스
유건데이타(주)
남양유업(주)
(주)오뚜기
(주)포스코이앤씨
(학)중앙대학교
신한투자증권(주)
엘에스전선(주)
(주)아모텍
(주)교보문고
SK텔레콤(주)
케이티텔레캅(주)
성남상공회의소
크림(주)
대원강업(주)
(주)한섬
(주)에이플러스에셋어드바이저
대한지방행정공제회
오씨아이홀딩스(주)
에스케이쉴더스(주)
(주)디에이치로지스틱스
(주)케이씨씨글라스
아이티컨버젼스(주)
(주)야놀자
(주)아이하트
(주)신동양기업
한일네트웍스(주)
비나텍(주)
(주)하누리
메가존클라우드 주식회사
(주)에이엔드
(주)인디시스템
슬리버
주성엔지니어링(주)
체인팜 주식회사
(주)블루비즈넷
(주)로그스택
한국교통안전공단
한국언론진흥재단
(주)하나투어
영림임업(주)
쿠도커뮤니케이션(주)
(주)삼익악기
한양디지텍㈜
리디(주)
(주)오페라살루따리스
한양여자대학교
풀무원다논(주)
메가존클라우드 주식회사
(주)비비드플러스
(주)알엠소프트
(주)사람인
(재)대구경북과학기술원
(주)케이티엔지니어링
넛지헬스케어(주)
(주)프람트테크놀로지
주식회사 에이블런
한국시험인증원(주)
(주)아리사코리아
인피니언테크놀로지스코리아(유)
(주)동인기연
한영회계법인
(주)아이에스시
근로복지공단
한국오에스지(주)
(주)글로벌스탠다드테크놀로지
(주)더존비즈온
한국소니전자(주)
(주)파트론
넛지헬스케어(주)
현항공산업(주)
(주)와이투솔루션
(주)가온칩스
(주)솔리드이엔지
(주)제주반도체
보은전자방송통신㈜
아이크래프트(주)
(주)티모넷
(주)에이프로
한국에스지에스(주)
현대엘리베이터서비스(주)
(주)무신사
㈜데이타메이션
(주)투게더앱스
(주)유스하이텍
(주)이노팩토리
케이엘정보통신(주)
(주)잇팩
(주)지케스
(주)아이브릭스
(주)위존
(주)비욘드이엔티
(주)맑은샘파트너스
(주)피피티웨어
(주)누리앱
(주)모두솔루션
(주)지엠피아이티
굿어스(주)
(주)넥스트아이씨티
(주)비제이시스템즈
(주)와이코퍼레이션
(주)클러버스
슬리버
엑시스아이
링크캠퍼스
(주)핀샷
(주)제너시스비비큐
한국과학기술연구원
한영회계법인
머크일렉트로닉머티리얼즈(주)
포레시아코리아(주)
(주)링크프라이스
(주)오케이포스
(주)링크프라이스
(주)일진코스메틱
(학)대전기독학원
(주)스맥
(주)프로텍
(주)데이터유니버스
(재)국악방송
(주)패스트뷰
(주)에이블런
에너지엑스(주)
(유)신원데이터넷
유디에스(주)
(주)모스트콘텐츠
(주)레오이노비젼
(주)백패커
(주)머스트잇
(주)비비드플러스
(주)비비드플러스
(주)비비드플러스
(주)비씨엠
(주)애드몽스
한국딥러닝(주)
(주)큐라에스
(주)벨르제이
스타법무법인
스타법무법인
미젤라화장품
(주)부스트랩
(의)삼광의료재단
넛지헬스케어(주)
(주)솔로몬텍
케이씨아이엠(주)
한국에스지에스(주)
(주)렉쎌
(주)에이티센스
하트비트 분석센터의원
케이크(주)
(주)아토베브코리아
(주)아토베브코리아
(주)인투인월드
한영회계법인
(주)한국정보기술단
신생공업(주)
(주)미래로시스템
(주)바이오넷
안진회계법인
파킹클라우드(주)
넥스콘테크놀러지(주)
이바코리아시스템(주)
유엘코리아 주식회사
(주)아이웍스
(주)테이슨
(주)캔랩
네오뉴트라(주)
(주)와이즈스톤
주식회사 에이블런
(주)이글루클라우드
(주)페스카로
(주)밀버스
(주)지엠디소프트
이룸컨설팅(주)
(주)예인
엔아이티서비스 주식회사
엔아이티서비스 주식회사
포인드(주)
(주)넥스블루

'''

# %%
wc = WordCloud(width=1000, height=600, background_color='white', random_state=0,font_path='NanumBarunGothic')
plt.imshow(wc.generate(text))
plt.axis('off')
plt.show()

# %%
# !conda install -y wikipedia
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - wikipedia
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
from wordcloud import WordCloud, STOPWORDS
import wikipedia
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from wordcloud import WordCloud, STOPWORDS
# ----> 2 import wikipedia
#
# ModuleNotFoundError: No module named 'wikipedia'

# %%
from wordcloud import WordCloud, STOPWORDS
import wikipedia
wiki = wikipedia.search('ironman') #영어로입력해야함
wiki = wikipedia.page(wiki[0])
text = wiki.content
stopwords=set(STOPWORDS)
wordcloud = WordCloud(background_color='white', colormap='winter',stopwords=stopwords).generate(text)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 2
#       1 from wordcloud import WordCloud, STOPWORDS
# ----> 2 import wikipedia
#       3 wiki = wikipedia.search('ironman') #영어로입력해야함
#       4 wiki = wikipedia.page(wiki[0])
#
# ModuleNotFoundError: No module named 'wikipedia'
